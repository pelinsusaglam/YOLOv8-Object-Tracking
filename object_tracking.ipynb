# %% [markdown]
# # YOLOv8 Nesne Takibi

# %% [markdown]
# ## Ortam Hazırlığı

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLOv8/object_tracking
# Out:
# /content/drive/MyDrive/YOLOv8/object_tracking

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ## Test// Tracking

# %%
# !yolo track model=yolov8n.pt source="data/test.mp4"
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.9s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/301) /content/drive/MyDrive/YOLOv8/object_tracking/data/test.mp4: 384x640 6 cars, 172.2ms
# video 1/1 (2/301) /content/drive/MyDrive/YOLOv8/object_tracking/data/test.mp4: 384x640 6 cars, 8.7ms
# video 1/1 (3/301) /content/drive/MyDrive/YOLOv8/object_tracking/data/test.mp4: 384x640 6 cars, 8.2ms
# video 1/1 (4/301) /content/drive/MyDrive/YOLOv8/object_tracking/data/test.mp4: 384x640 6 cars, 7.9ms
# ...
